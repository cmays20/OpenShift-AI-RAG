# %%
# Install dependencies (only needed once per environment)
# !pip install requests beautifulsoup4 llama_stack llama-stack-client
# Out:
# Requirement already satisfied: requests in c:\users\cmays\appdata\local\programs\python\python312\lib\site-packages (2.32.5)
# Requirement already satisfied: beautifulsoup4 in c:\users\cmays\appdata\local\programs\python\python312\lib\site-packages (4.14.2)
# Collecting llama_stack
#   Downloading llama_stack-0.3.2-py3-none-any.whl.metadata (15 kB)
# Collecting llama-stack-client
#   Downloading llama_stack_client-0.3.2-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\cmays\appdata\local\programs\python\python312\lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cmays\appdata\local\programs\python\python312\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cmays\appdata\local\programs\python\python312\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cmays\appdata\local\programs\python\python312\lib\site-packages (from requests) (2025.11.12)
# Requirement already satisfied: soupsieve>1.2 in c:\users\cmays\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\cmays\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4) (4.15.0)
# Collecting aiohttp (from llama_stack)
#   Downloading aiohttp-3.13.2-cp312-cp312-win_amd64.whl.metadata (8.4 kB)
# Collecting fastapi<1.0,>=0.115.0 (from llama_stack)
#   Downloading fastapi-0.121.2-py3-none-any.whl.metadata (28 kB)
# Collecting fire (from llama_stack)
#   Using cached fire-0.7.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: httpx in c:\users\cmays\appdata\local\programs\python\python312\lib\site-packages (from llama_stack) (0.28.1)
# Requirement already satisfied: jinja2>=3.1.6 in c:\users\cmays\appdata\local\programs\python\python312\lib\site-packages (from llama_stack) (3.1.6)
# Requirement already satisfied: jsonschema in c:\users\cmays\appdata\local\programs\python\python312\lib\site-packages (from llama_stack) (4.25.1)
# Collecting openai>=1.107 (from llama_stack)
#   Downloading openai-2.8.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: prompt-toolkit in c:\users\cmays\appdata\local\programs\python\python312\lib\site-packages (from llama_stack) (3.0.52)
# Collecting python-dotenv (from llama_stack)
#   Downloading python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Collecting pyjwt>=2.10.0 (from pyjwt[crypto]>=2.10.0->llama_stack)
#   Downloading PyJWT-2.10.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting pydantic>=2.11.9 (from llama_stack)
#   Downloading pydantic-2.12.4-py3-none-any.whl.metadata (89 kB)
# Collecting rich (from llama_stack)
#   Downloading rich-14.2.0-py3-none-any.whl.metadata (18 kB)
# Collecting starlette (from llama_stack)
#   Downloading starlette-0.50.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting termcolor (from llama_stack)
#   Downloading termcolor-3.2.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting tiktoken (from llama_stack)
#   Downloading tiktoken-0.12.0-cp312-cp312-win_amd64.whl.metadata (6.9 kB)
# Collecting pillow (from llama_stack)
#   Downloading pillow-12.0.0-cp312-cp312-win_amd64.whl.metadata (9.0 kB)
# Requirement already satisfied: h11>=0.16.0 in c:\users\cmays\appdata\local\programs\python\python312\lib\site-packages (from llama_stack) (0.16.0)
# Collecting python-multipart>=0.0.20 (from llama_stack)
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Collecting uvicorn>=0.34.0 (from llama_stack)
#   Downloading uvicorn-0.38.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting opentelemetry-sdk>=1.30.0 (from llama_stack)
#   Downloading opentelemetry_sdk-1.38.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-http>=1.30.0 (from llama_stack)
#   Downloading opentelemetry_exporter_otlp_proto_http-1.38.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting aiosqlite>=0.21.0 (from llama_stack)
#   Downloading aiosqlite-0.21.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting asyncpg (from llama_stack)
#   Downloading asyncpg-0.30.0-cp312-cp312-win_amd64.whl.metadata (5.2 kB)
# Collecting sqlalchemy>=2.0.41 (from sqlalchemy[asyncio]>=2.0.41->llama_stack)
#   Downloading sqlalchemy-2.0.44-cp312-cp312-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\cmays\appdata\local\programs\python\python312\lib\site-packages (from llama-stack-client) (4.11.0)
# Collecting click (from llama-stack-client)
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting distro<2,>=1.7.0 (from llama-stack-client)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting pandas (from llama-stack-client)
#   Downloading pandas-2.3.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting pyaml (from llama-stack-client)
#   Using cached pyaml-25.7.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: sniffio in c:\users\cmays\appdata\local\programs\python\python312\lib\site-packages (from llama-stack-client) (1.3.1)
# Collecting tqdm (from llama-stack-client)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting starlette (from llama_stack)
#   Downloading starlette-0.49.3-py3-none-any.whl.metadata (6.4 kB)
# Collecting annotated-doc>=0.0.2 (from fastapi<1.0,>=0.115.0->llama_stack)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: httpcore==1.* in c:\users\cmays\appdata\local\programs\python\python312\lib\site-packages (from httpx->llama_stack) (1.0.9)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\cmays\appdata\local\programs\python\python312\lib\site-packages (from jinja2>=3.1.6->llama_stack) (3.0.3)
# Collecting jiter<1,>=0.10.0 (from openai>=1.107->llama_stack)
#   Downloading jiter-0.12.0-cp312-cp312-win_amd64.whl.metadata (5.3 kB)
# Collecting googleapis-common-protos~=1.52 (from opentelemetry-exporter-otlp-proto-http>=1.30.0->llama_stack)
#   Downloading googleapis_common_protos-1.72.0-py3-none-any.whl.metadata (9.4 kB)
# Collecting opentelemetry-api~=1.15 (from opentelemetry-exporter-otlp-proto-http>=1.30.0->llama_stack)
#   Downloading opentelemetry_api-1.38.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.38.0 (from opentelemetry-exporter-otlp-proto-http>=1.30.0->llama_stack)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.38.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.38.0 (from opentelemetry-exporter-otlp-proto-http>=1.30.0->llama_stack)
#   Downloading opentelemetry_proto-1.38.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting protobuf<7.0,>=5.0 (from opentelemetry-proto==1.38.0->opentelemetry-exporter-otlp-proto-http>=1.30.0->llama_stack)
#   Downloading protobuf-6.33.1-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Collecting opentelemetry-semantic-conventions==0.59b0 (from opentelemetry-sdk>=1.30.0->llama_stack)
#   Downloading opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl.metadata (2.4 kB)
# Collecting importlib-metadata<8.8.0,>=6.0 (from opentelemetry-api~=1.15->opentelemetry-exporter-otlp-proto-http>=1.30.0->llama_stack)
#   Downloading importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting annotated-types>=0.6.0 (from pydantic>=2.11.9->llama_stack)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic>=2.11.9->llama_stack)
#   Downloading pydantic_core-2.41.5-cp312-cp312-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic>=2.11.9->llama_stack)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting cryptography>=3.4.0 (from pyjwt[crypto]>=2.10.0->llama_stack)
#   Downloading cryptography-46.0.3-cp311-abi3-win_amd64.whl.metadata (5.7 kB)
# Collecting greenlet>=1 (from sqlalchemy>=2.0.41->sqlalchemy[asyncio]>=2.0.41->llama_stack)
#   Downloading greenlet-3.2.4-cp312-cp312-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: colorama in c:\users\cmays\appdata\local\programs\python\python312\lib\site-packages (from tqdm->llama-stack-client) (0.4.6)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp->llama_stack)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp->llama_stack)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\cmays\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->llama_stack) (25.4.0)
# Collecting frozenlist>=1.1.1 (from aiohttp->llama_stack)
#   Downloading frozenlist-1.8.0-cp312-cp312-win_amd64.whl.metadata (21 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->llama_stack)
#   Downloading multidict-6.7.0-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp->llama_stack)
#   Downloading propcache-0.4.1-cp312-cp312-win_amd64.whl.metadata (14 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp->llama_stack)
#   Downloading yarl-1.22.0-cp312-cp312-win_amd64.whl.metadata (77 kB)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\cmays\appdata\local\programs\python\python312\lib\site-packages (from jsonschema->llama_stack) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\cmays\appdata\local\programs\python\python312\lib\site-packages (from jsonschema->llama_stack) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\cmays\appdata\local\programs\python\python312\lib\site-packages (from jsonschema->llama_stack) (0.29.0)
# Collecting numpy>=1.26.0 (from pandas->llama-stack-client)
#   Downloading numpy-2.3.5-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\cmays\appdata\local\programs\python\python312\lib\site-packages (from pandas->llama-stack-client) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas->llama-stack-client)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\cmays\appdata\local\programs\python\python312\lib\site-packages (from pandas->llama-stack-client) (2025.2)
# Requirement already satisfied: wcwidth in c:\users\cmays\appdata\local\programs\python\python312\lib\site-packages (from prompt-toolkit->llama_stack) (0.2.14)
# Requirement already satisfied: PyYAML in c:\users\cmays\appdata\local\programs\python\python312\lib\site-packages (from pyaml->llama-stack-client) (6.0.3)
# Collecting markdown-it-py>=2.2.0 (from rich->llama_stack)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\cmays\appdata\local\programs\python\python312\lib\site-packages (from rich->llama_stack) (2.19.2)
# Collecting regex>=2022.1.18 (from tiktoken->llama_stack)
#   Downloading regex-2025.11.3-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\cmays\appdata\local\programs\python\python312\lib\site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.0->llama_stack) (2.0.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->llama_stack)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: six>=1.5 in c:\users\cmays\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas->llama-stack-client) (1.17.0)
# Requirement already satisfied: pycparser in c:\users\cmays\appdata\local\programs\python\python312\lib\site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.0->llama_stack) (2.23)
# Collecting zipp>=3.20 (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api~=1.15->opentelemetry-exporter-otlp-proto-http>=1.30.0->llama_stack)
#   Downloading zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Downloading llama_stack-0.3.2-py3-none-any.whl (3.6 MB)
#    ---------------------------------------- 0.0/3.6 MB ? eta -:--:--
#    -------- ------------------------------- 0.8/3.6 MB 3.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.6/3.6 MB 4.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.6/3.6 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------- 3.6/3.6 MB 4.5 MB/s eta 0:00:00
# Downloading llama_stack_client-0.3.2-py3-none-any.whl (425 kB)
# Downloading aiosqlite-0.21.0-py3-none-any.whl (15 kB)
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading fastapi-0.121.2-py3-none-any.whl (109 kB)
# Downloading openai-2.8.0-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ------------------------------ --------- 0.8/1.0 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 4.9 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_http-1.38.0-py3-none-any.whl (19 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.38.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.38.0-py3-none-any.whl (72 kB)
# Downloading opentelemetry_sdk-1.38.0-py3-none-any.whl (132 kB)
# Downloading opentelemetry_api-1.38.0-py3-none-any.whl (65 kB)
# Downloading opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl (207 kB)
# Downloading pydantic-2.12.4-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp312-cp312-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    -------------------- ------------------- 1.0/2.0 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 5.6 MB/s eta 0:00:00
# Downloading PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading sqlalchemy-2.0.44-cp312-cp312-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ------------------------ --------------- 1.3/2.1 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 6.0 MB/s eta 0:00:00
# Downloading starlette-0.49.3-py3-none-any.whl (74 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading uvicorn-0.38.0-py3-none-any.whl (68 kB)
# Downloading click-8.3.1-py3-none-any.whl (108 kB)
# Downloading aiohttp-3.13.2-cp312-cp312-win_amd64.whl (453 kB)
# Downloading asyncpg-0.30.0-cp312-cp312-win_amd64.whl (621 kB)
#    ---------------------------------------- 0.0/621.1 kB ? eta -:--:--
#    ---------------------------------------- 621.1/621.1 kB 5.8 MB/s eta 0:00:00
# Using cached fire-0.7.1-py3-none-any.whl (115 kB)
# Downloading pandas-2.3.3-cp312-cp312-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/11.0 MB 6.7 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.9/11.0 MB 7.0 MB/s eta 0:00:02
#    --------------- ------------------------ 4.2/11.0 MB 7.0 MB/s eta 0:00:01
#    -------------------- ------------------- 5.8/11.0 MB 7.0 MB/s eta 0:00:01
#    -------------------------- ------------- 7.3/11.0 MB 7.3 MB/s eta 0:00:01
#    -------------------------------- ------- 8.9/11.0 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 7.4 MB/s eta 0:00:00
# Downloading pillow-12.0.0-cp312-cp312-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------- ----------------------------- 1.8/7.0 MB 9.1 MB/s eta 0:00:01
#    -------------------- ------------------- 3.7/7.0 MB 9.1 MB/s eta 0:00:01
#    ------------------------------- -------- 5.5/7.0 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 9.2 MB/s eta 0:00:00
# Using cached pyaml-25.7.0-py3-none-any.whl (26 kB)
# Downloading python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Downloading rich-14.2.0-py3-none-any.whl (243 kB)
# Downloading termcolor-3.2.0-py3-none-any.whl (7.7 kB)
# Downloading tiktoken-0.12.0-cp312-cp312-win_amd64.whl (878 kB)
#    ---------------------------------------- 0.0/878.7 kB ? eta -:--:--
#    ---------------------------------------- 878.7/878.7 kB 7.9 MB/s eta 0:00:00
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading cryptography-46.0.3-cp311-abi3-win_amd64.whl (3.5 MB)
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    -------------------- ------------------- 1.8/3.5 MB 10.1 MB/s eta 0:00:01
#    ---------------------------------------- 3.5/3.5 MB 9.5 MB/s eta 0:00:00
# Downloading frozenlist-1.8.0-cp312-cp312-win_amd64.whl (44 kB)
# Downloading googleapis_common_protos-1.72.0-py3-none-any.whl (297 kB)
# Downloading greenlet-3.2.4-cp312-cp312-win_amd64.whl (299 kB)
# Downloading jiter-0.12.0-cp312-cp312-win_amd64.whl (205 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading multidict-6.7.0-cp312-cp312-win_amd64.whl (46 kB)
# Downloading numpy-2.3.5-cp312-cp312-win_amd64.whl (12.8 MB)
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ------ --------------------------------- 2.1/12.8 MB 10.7 MB/s eta 0:00:02
#    ------------- -------------------------- 4.2/12.8 MB 10.5 MB/s eta 0:00:01
#    ------------------- -------------------- 6.3/12.8 MB 10.7 MB/s eta 0:00:01
#    --------------------------- ------------ 8.7/12.8 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.0/12.8 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------- 12.8/12.8 MB 10.7 MB/s eta 0:00:00
# Downloading propcache-0.4.1-cp312-cp312-win_amd64.whl (41 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading regex-2025.11.3-cp312-cp312-win_amd64.whl (277 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading yarl-1.22.0-cp312-cp312-win_amd64.whl (87 kB)
# Downloading importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading protobuf-6.33.1-cp310-abi3-win_amd64.whl (436 kB)
# Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Installing collected packages: pytz, zipp, typing-inspection, tqdm, termcolor, regex, python-multipart, python-dotenv, pyjwt, pydantic-core, pyaml, protobuf, propcache, pillow, numpy, multidict, mdurl, jiter, greenlet, frozenlist, distro, click, asyncpg, annotated-types, annotated-doc, aiosqlite, aiohappyeyeballs, yarl, uvicorn, tiktoken, starlette, sqlalchemy, pydantic, pandas, opentelemetry-proto, markdown-it-py, importlib-metadata, googleapis-common-protos, fire, cryptography, aiosignal, rich, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, openai, fastapi, aiohttp, opentelemetry-semantic-conventions, llama-stack-client, opentelemetry-sdk, opentelemetry-exporter-otlp-proto-http, llama_stack
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.13.2 aiosignal-1.4.0 aiosqlite-0.21.0 annotated-doc-0.0.4 annotated-types-0.7.0 asyncpg-0.30.0 click-8.3.1 cryptography-46.0.3 distro-1.9.0 fastapi-0.121.2 fire-0.7.1 frozenlist-1.8.0 googleapis-common-protos-1.72.0 greenlet-3.2.4 importlib-metadata-8.7.0 jiter-0.12.0 llama-stack-client-0.3.2 llama_stack-0.3.2 markdown-it-py-4.0.0 mdurl-0.1.2 multidict-6.7.0 numpy-2.3.5 openai-2.8.0 opentelemetry-api-1.38.0 opentelemetry-exporter-otlp-proto-common-1.38.0 opentelemetry-exporter-otlp-proto-http-1.38.0 opentelemetry-proto-1.38.0 opentelemetry-sdk-1.38.0 opentelemetry-semantic-conventions-0.59b0 pandas-2.3.3 pillow-12.0.0 propcache-0.4.1 protobuf-6.33.1 pyaml-25.7.0 pydantic-2.12.4 pydantic-core-2.41.5 pyjwt-2.10.1 python-dotenv-1.2.1 python-multipart-0.0.20 pytz-2025.2 regex-2025.11.3 rich-14.2.0 sqlalchemy-2.0.44 starlette-0.49.3 termcolor-3.2.0 tiktoken-0.12.0 tqdm-4.67.1 typing-inspection-0.4.2 uvicorn-0.38.0 yarl-1.22.0 zipp-3.23.0
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: C:\Users\cmays\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
import re
from bs4 import BeautifulSoup

# Read the HTML from a local file
html_file_path = "agenda.html"

with open(html_file_path, "r", encoding="utf-8") as f:
    html_content = f.read()

soup = BeautifulSoup(html_content, "html.parser")

sessions = []

# Find all panel containers
panels = soup.select("div.panel.panel-default")

for panel in panels:
    # Extract the day from the panel heading
    day = None
    panel_heading = panel.select_one("div.panel-heading h4.panel-title a")
    if panel_heading:
        day = panel_heading.get_text(strip=True)

    # Find all agenda items within this panel
    panel_body = panel.select_one("div.panel-collapse")
    if not panel_body:
        continue

    agenda_items = panel_body.select("div.agendaItem.col-sm-12")

    for item in agenda_items:
        # Time section (left side - col-sm-2)
        time_section = item.select_one("div.agendaTime.col-sm-2")

        session_time = None
        room = None
        track_tags = []

        if time_section:
            time_tag = time_section.select_one("div.agendaTime02")
            session_time = time_tag.get_text(strip=True) if time_tag else None

            loc_tag = time_section.select_one("div.agendaLocation02")
            room = loc_tag.get_text(strip=True) if loc_tag else None

            # Track tags from divs with class matching agendaTag0X pattern
            for div in time_section.find_all("div"):
                if div.get("class"):
                    for class_name in div.get("class"):
                        if class_name.startswith("agendaTag"):
                            track_text = div.get_text(strip=True)
                            if track_text:
                                track_tags.append(track_text)

        # Content section (right side - col-sm-10)
        content_section = item.select_one("div.agendaItem.col-sm-10")

        title = None
        subtitle = None
        present_text = ""
        speakers = []

        if content_section:
            # Get all trackTitle divs
            track_titles = content_section.select("div.trackTitle")

            # Filter out the track category title (it has tag03 class)
            if track_titles:
                actual_titles = [t for t in track_titles if not any(c.startswith('tag') for c in t.get('class', []))]
                if actual_titles:
                    title = actual_titles[0].get_text(strip=True)
                elif track_titles:
                    title = track_titles[0].get_text(strip=True)

            # Subtitle
            subtitle_tag = content_section.select_one("div.trackSubTitle")
            subtitle = subtitle_tag.get_text(strip=True) if subtitle_tag else None

            # Description/presenter info
            present_tag = content_section.select_one("div.agendaPresent")
            if present_tag:
                present_text = present_tag.get_text("\n", strip=True)

            # Extract speakers from paragraph tags
            speaker_paragraphs = content_section.select("p")
            for p in speaker_paragraphs:
                # Get text with line breaks preserved
                speaker_text = p.get_text("\n", strip=True)

                # Split by line breaks to get individual speakers
                speaker_lines = [line.strip() for line in speaker_text.split('\n') if line.strip()]

                for line in speaker_lines:
                    # Skip lines that are just labels or empty
                    if not line or line.lower().startswith('panelist') or line.lower().startswith('moderator'):
                        continue

                    # Check for confirmation status
                    confirmed = False
                    invited = False

                    # Look for (confirmed) or (invited) at the end
                    if re.search(r'\(confirmed\)\s*$', line, re.IGNORECASE):
                        confirmed = True
                    elif re.search(r'\(invited\)\s*$', line, re.IGNORECASE):
                        invited = True

                    # Remove status markers for parsing
                    clean_line = re.sub(r'\s*\([^)]*\)\s*$', '', line)

                    # Try to split by " - " to separate name from title/org
                    if ' - ' in clean_line:
                        parts = clean_line.split(' - ', 1)
                        name = parts[0].strip()

                        # Try to split title and organization
                        title_org = parts[1].strip() if len(parts) > 1 else ""

                        # Try to split by comma to get title and org
                        if ',' in title_org:
                            role_parts = title_org.split(',', 1)
                            role = role_parts[0].strip()
                            organization = role_parts[1].strip() if len(role_parts) > 1 else ""
                        else:
                            role = title_org
                            organization = ""

                        speakers.append({
                            "name": name,
                            "role": role,
                            "organization": organization,
                            "confirmed": confirmed,
                            "invited": invited
                        })

        # Build description from subtitle + agendaPresent
        parts = []
        if subtitle:
            parts.append(subtitle)
        if present_text:
            parts.append(present_text)
        description = "\n\n".join(parts) if parts else None

        # Extract sponsor from agendaPresent or from links
        sponsor = None
        if content_section:
            present_tag = content_section.select_one("div.agendaPresent")
            if present_tag:
                # Check for "Sponsored By" text
                m = re.search(r"Sponsored\s+By[:\-]?\s*(.+)", present_text, flags=re.IGNORECASE)
                if m:
                    sponsor = m.group(1).strip()
                else:
                    # Check for links in agendaPresent
                    sponsor_link = present_tag.find("a")
                    if sponsor_link:
                        sponsor = sponsor_link.get_text(strip=True)

        # Use track tags found in the time section
        tracks = track_tags

        # Only add sessions that have a title
        if title:
            sessions.append({
                "title": title,
                "day": day,
                "time": session_time,
                "room": room,
                "description": description,
                "tracks": tracks,
                "sponsor": sponsor,
                "speakers": speakers,
            })

print(f"Found {len(sessions)} sessions")
for s in sessions:  # show first 10 for sanity check
    print(s)
# Out:
# Found 85 sessions
# {'title': 'Squadron Commanders Course (Invitation Only)', 'day': 'Monday 1 December 2025', 'time': '0800 - 1700', 'room': 'Wisteria/Sunflower', 'description': None, 'tracks': ['Human Capital'], 'sponsor': None, 'speakers': []}
# {'title': '19th Hole Social', 'day': 'Monday 1 December 2025', 'time': '1400 - 1600', 'room': 'Riverbend Pavilion', 'description': 'Sponsored By:\nSalesForce', 'tracks': [], 'sponsor': 'SalesForce', 'speakers': []}
# {'title': 'Registration', 'day': 'Tuesday 2 December 2025', 'time': '0800 - 1700', 'room': '2nd Floor Ballroom Level', 'description': 'Sponsored By:\nPeraton', 'tracks': [], 'sponsor': 'Peraton', 'speakers': []}
# {'title': 'XCOMM Executive Council (Invitation Only)', 'day': 'Tuesday 2 December 2025', 'time': '0800 - 1700', 'room': 'Sunflower', 'description': None, 'tracks': ['Human Capital'], 'sponsor': None, 'speakers': []}
# {'title': 'Squadron Commanders Course (Invitation Only)', 'day': 'Tuesday 2 December 2025', 'time': '0800 - 1700', 'room': 'Wisteria/Sunflower', 'description': None, 'tracks': ['Human Capital'], 'sponsor': None, 'speakers': []}
# {'title': '17X Functional Advisory Council (Invitation Only)', 'day': 'Tuesday 2 December 2025', 'time': '0800 - 1700', 'room': 'Goldenrod Room', 'description': None, 'tracks': ['Human Capital'], 'sponsor': None, 'speakers': []}
# {'title': 'Capture the Flag Competition - Middle and High School -View Flyer >>', 'day': 'Tuesday 2 December 2025', 'time': '1000 - 1700', 'room': 'Cibolo Ballroom 3-4', 'description': 'Sponsored By:\nParsons Corporation', 'tracks': [], 'sponsor': 'Parsons Corporation', 'speakers': []}
# {'title': '19th Hole Social', 'day': 'Tuesday 2 December 2025', 'time': '1300 -1500', 'room': 'Event Lawn 3', 'description': 'Sponsored By:\nTrellix', 'tracks': [], 'sponsor': 'Trellix', 'speakers': []}
# {'title': 'Acquisition Track', 'day': 'Tuesday 2 December 2025', 'time': '1400 - 1430', 'room': 'Cibolo Ballroom 8-9', 'description': 'AFLCMC/HN\n\nAcquisition Track Sponsored by:\nSemper Valens Solutions, Inc.', 'tracks': ['Acquisition Track'], 'sponsor': 'Semper Valens Solutions, Inc.', 'speakers': []}
# {'title': 'Acquisition Track', 'day': 'Tuesday 2 December 2025', 'time': '1430 - 1700', 'room': 'Cibolo Ballroom 8-9', 'description': 'HN Presentations to Industry\n\nAcquisition Track Sponsored by:\nSemper Valens Solutions, Inc.', 'tracks': ['Cibolo Ballroom 8-9'], 'sponsor': 'Semper Valens Solutions, Inc.', 'speakers': []}
# {'title': 'Small Business Track', 'day': 'Tuesday 2 December 2025', 'time': '1415 - 1500', 'room': 'Cibolo Ballroom 1-2', 'description': 'CMMC & ATO Discussion', 'tracks': ['Small Business Track'], 'sponsor': None, 'speakers': [{'name': 'Mr. Rob Adams', 'role': 'OCO&CWS AODR', 'organization': 'USAF (', 'confirmed': False, 'invited': False}, {'name': 'Mr. Max Aulakh', 'role': 'Co-Founder', 'organization': 'Ignyte Assurance Platform', 'confirmed': False, 'invited': False}]}
# {'title': 'Small Business Track', 'day': 'Tuesday 2 December 2025', 'time': '1515 - 1600', 'room': 'Cibolo Ballroom 1-2', 'description': 'AFWERX in Action: Fueling the Future of Defense Innovation', 'tracks': ['Small Business Track'], 'sponsor': None, 'speakers': [{'name': 'Ms. Melissa Garmo', 'role': 'Acquisition Program Manager', 'organization': 'SpaceWERX (', 'confirmed': False, 'invited': False}]}
# {'title': 'Welcome Reception', 'day': 'Tuesday 2 December 2025', 'time': '1800 - 2000', 'room': 'Event Lawn 2', 'description': 'Sponsored By:\nGDIT', 'tracks': [], 'sponsor': 'GDIT', 'speakers': []}
# {'title': 'Registration', 'day': 'Wednesday 3 December 2025', 'time': '0630 - 1800', 'room': '2nd Floor Ballroom Level', 'description': 'Sponsored By:\nPeraton', 'tracks': [], 'sponsor': 'Peraton', 'speakers': []}
# {'title': 'Breakfast', 'day': 'Wednesday 3 December 2025', 'time': '0700 - 0800', 'room': 'Grand Oaks Ballroom', 'description': 'Sponsored By:\nCiena', 'tracks': [], 'sponsor': 'Ciena', 'speakers': []}
# {'title': 'Exhibit Hall Break', 'day': 'Wednesday 3 December 2025', 'time': '0700 - 1600', 'room': 'Grand Oaks Ballroom', 'description': 'Break Sponsored By:\nCiena', 'tracks': [], 'sponsor': 'Ciena', 'speakers': []}
# {'title': 'Capture the Flag Competition - College/University -View Flyer >>', 'day': 'Wednesday 3 December 2025', 'time': '0800 - 1600', 'room': 'Cibolo Ballroom 3-4', 'description': 'Sponsored By:\nParsons Corporation', 'tracks': [], 'sponsor': 'Parsons Corporation', 'speakers': []}
# {'title': 'General Session', 'day': 'Wednesday 3 December 2025', 'time': '0800 - 0845', 'room': 'Cibolo Ballroom 5-7', 'description': 'Opening, Welcome, and Administrative Remarks', 'tracks': ['General Session'], 'sponsor': None, 'speakers': []}
# {'title': 'Keynote Session', 'day': 'Wednesday 3 December 2025', 'time': '0845 - 0930', 'room': 'Cibolo Ballroom 5-7', 'description': '16 AF Update', 'tracks': ['Keynote Session'], 'sponsor': None, 'speakers': [{'name': 'SES Brian Cook', 'role': 'Technical Director', 'organization': 'Sixteenth Air Force (', 'confirmed': False, 'invited': False}]}
# {'title': 'General Session', 'day': 'Wednesday 3 December 2025', 'time': '0930 - 1015', 'room': 'Cibolo Ballroom 5-7', 'description': 'SAF/CN', 'tracks': ['General Session'], 'sponsor': None, 'speakers': []}
# {'title': 'Breakout Session Track', 'day': 'Wednesday 3 December 2025', 'time': '0930 - 1015', 'room': 'Cibolo Ballroom 1-2', 'description': 'Government Healthcare Session', 'tracks': ['Breakout Track'], 'sponsor': None, 'speakers': []}
# {'title': 'Human Capital', 'day': 'Wednesday 3 December 2025', 'time': '0930 - 1030', 'room': 'Cibolo Ballroom 8-9', 'description': 'Civilian Career Field Update', 'tracks': ['Human Capital'], 'sponsor': None, 'speakers': []}
# {'title': 'Exhibit Hall Break', 'day': 'Wednesday 3 December 2025', 'time': '1015 - 1030', 'room': 'Grand Oaks Ballroom', 'description': 'Break Sponsored By:\nCiena', 'tracks': [], 'sponsor': 'Ciena', 'speakers': []}
# {'title': 'General Session', 'day': 'Wednesday 3 December 2025', 'time': '1030 - 1145', 'room': 'Cibolo Ballroom 5-7', 'description': None, 'tracks': ['General Session'], 'sponsor': None, 'speakers': []}
# {'title': 'Small Business Track', 'day': 'Wednesday 3 December 2025', 'time': '1030 - 1145', 'room': 'Cibolo Ballroom 1-2', 'description': 'Small Business Government Contracting Panel', 'tracks': ['Small Business Track'], 'sponsor': None, 'speakers': [{'name': 'Mr. Jose Rivera', 'role': 'Vice President', 'organization': 'Enterprise Digital Solutions, SAIC (', 'confirmed': False, 'invited': False}, {'name': 'Mr. Mario Thompson', 'role': 'Procurement Analyst', 'organization': 'Mission and Installation Contracting Command (', 'confirmed': False, 'invited': False}, {'name': 'Ms. Laurie Sayles', 'role': 'President and CEO', 'organization': 'CivilityMS (', 'confirmed': False, 'invited': False}]}
# {'title': 'Human Capital', 'day': 'Wednesday 3 December 2025', 'time': '1030 - 1145', 'room': 'Cibolo Ballroom 8-9', 'description': '1D7 Career Field Update', 'tracks': ['Human Capital'], 'sponsor': None, 'speakers': []}
# {'title': 'Exhibit Hall Break', 'day': 'Wednesday 3 December 2025', 'time': '1145 - 1245', 'room': 'Grand Oaks Ballroom', 'description': 'Break Sponsored By:\nCiena', 'tracks': [], 'sponsor': 'Ciena', 'speakers': []}
# {'title': 'Technology Showcase Theater Presentations', 'day': 'Wednesday 3 December 2025', 'time': '1145 - 1245', 'room': 'Begonia/BluebonnetBottlebrush/Dogwood', 'description': 'Tech Showcases Sponsored by:\nSemper Valens Solutions, Inc.\nPresentations by:\nCohesity, Inc.\n|\nMANTECH\n|\nRed Hat\n|\nTrellix', 'tracks': ['Tech Showcase'], 'sponsor': 'Semper Valens Solutions, Inc.', 'speakers': []}
# {'title': 'Human Capital', 'day': 'Wednesday 3 December 2025', 'time': '1145 - 1245', 'room': 'Cibolo Ballroom 8-9', 'description': '17X Career Field Update', 'tracks': ['Human Capital'], 'sponsor': None, 'speakers': []}
# {'title': 'Keynote Lunch', 'day': 'Wednesday 3 December 2025', 'time': '1245 - 1415', 'room': 'Cibolo Ballroom 5-7', 'description': 'Keynote Luncheon Sponsored by:\nCanonical Group Limited', 'tracks': ['Keynote Session'], 'sponsor': 'Canonical Group Limited', 'speakers': []}
# {'title': 'Exhibit Hall Break', 'day': 'Wednesday 3 December 2025', 'time': '1415 - 1445', 'room': 'Grand Oaks Ballroom', 'description': 'Break Sponsored By:\nCiena', 'tracks': [], 'sponsor': 'Ciena', 'speakers': []}
# {'title': 'Technology Showcase Theater Presentations', 'day': 'Wednesday 3 December 2025', 'time': '1415 - 1515', 'room': 'Begonia/BluebonnetBottlebrush/Dogwood', 'description': 'Tech Showcases Sponsored by:\nSemper Valens Solutions, Inc.\nPresentations by:\nOptiv + ClearShark\n|\nSealing Technologies\n|\nServiceNow\n|\nSolarWinds', 'tracks': ['Tech Showcase'], 'sponsor': 'Semper Valens Solutions, Inc.', 'speakers': []}
# {'title': 'Human Capital', 'day': 'Wednesday 3 December 2025', 'time': '1415 - 1515', 'room': 'Cibolo Ballroom 8-9', 'description': '1B4 and 1N4 Career Field Update', 'tracks': ['Human Capital'], 'sponsor': None, 'speakers': []}
# {'title': 'General Session', 'day': 'Wednesday 3 December 2025', 'time': '1445 - 1600', 'room': 'Cibolo Ballroom 5-7', 'description': 'Army Signal and Cyber Panel', 'tracks': ['General Session'], 'sponsor': None, 'speakers': []}
# {'title': 'Breakout Track', 'day': 'Wednesday 3 December 2025', 'time': '1445 - 1600', 'room': 'Cibolo Ballroom 5-7', 'description': 'Cyber Career Growth: Navigating Opportunities for Military and Civilian Pros', 'tracks': ['Breakout Track'], 'sponsor': None, 'speakers': []}
# {'title': 'Breakout Session Track', 'day': 'Wednesday 3 December 2025', 'time': '1445 - 1600', 'room': 'Cibolo Ballroom 8-9', 'description': 'Cyber Wing Commander Panel', 'tracks': ['Breakout Track'], 'sponsor': None, 'speakers': []}
# {'title': 'Exhibit Hall Break', 'day': 'Wednesday 3 December 2025', 'time': '1600 - 1615', 'room': 'Grand Oaks Ballroom', 'description': 'Break Sponsored By:\nCiena', 'tracks': [], 'sponsor': 'Ciena', 'speakers': []}
# {'title': 'Keynote Session', 'day': 'Wednesday 3 December 2025', 'time': '1615 - 1700', 'room': 'Cibolo Ballroom 5-7', 'description': None, 'tracks': ['Keynote Session'], 'sponsor': None, 'speakers': []}
# {'title': 'Networking Hospitality Events', 'day': 'Wednesday 3 December 2025', 'time': '1700 - 1900', 'room': 'Periwinkle/Verbena | Whisteria/Sunflower', 'description': 'Sponsored By:\nAkima\n|\nGovly', 'tracks': [], 'sponsor': 'Akima', 'speakers': []}
# {'title': 'Wounded Warrior and Military Family Casino Night Event', 'day': 'Wednesday 3 December 2025', 'time': '2000 - 2200', 'room': 'Cibolo Ballroom 5-7', 'description': None, 'tracks': [], 'sponsor': None, 'speakers': []}
# {'title': 'Registration', 'day': 'Thursday 4 December 2025', 'time': '0700 - 1600', 'room': '2nd Floor Ballroom Level', 'description': 'Sponsored By:\nPeraton', 'tracks': [], 'sponsor': 'Peraton', 'speakers': []}
# {'title': 'Breakfast', 'day': 'Thursday 4 December 2025', 'time': '0700 - 0800', 'room': 'Grand Oaks Ballroom', 'description': 'Sponsored By:\nQualys', 'tracks': [], 'sponsor': 'Qualys', 'speakers': []}
# {'title': 'Exhibit Hall Break', 'day': 'Thursday 4 December 2025', 'time': '0700 - 1600', 'room': 'Grand Oaks Ballroom', 'description': 'Break Sponsored By:\nQualys', 'tracks': [], 'sponsor': 'Qualys', 'speakers': []}
# {'title': 'Capture the Flag Competition - Military/Industry day -View Flyer >>', 'day': 'Thursday 4 December 2025', 'time': '0800 - 1600', 'room': 'Cibolo Ballroom 3-4', 'description': 'Sponsored By:\nParsons Corporation', 'tracks': [], 'sponsor': 'Parsons Corporation', 'speakers': []}
# {'title': 'General Session', 'day': 'Thursday 4 December 2025', 'time': '0800 - 0815', 'room': 'Cibolo Ballroom 5-7', 'description': 'Opening Remarks', 'tracks': ['General Session'], 'sponsor': None, 'speakers': []}
# {'title': 'General Session', 'day': 'Thursday 4 December 2025', 'time': '0815 - 0830', 'room': 'Cibolo Ballroom 5-7', 'description': 'AFCEA International', 'tracks': ['General Session'], 'sponsor': None, 'speakers': []}
# {'title': 'Keynote Session', 'day': 'Thursday 4 December 2025', 'time': '0830 - 0915', 'room': 'Cibolo Ballroom 5-7', 'description': 'AFLCMC', 'tracks': ['Keynote Session'], 'sponsor': None, 'speakers': []}
# {'title': 'General Session', 'day': 'Thursday 4 December 2025', 'time': '0915 - 1000', 'room': 'Cibolo Ballroom 5-7', 'description': 'DISA', 'tracks': ['General Session'], 'sponsor': None, 'speakers': []}
# {'title': 'Human Capital', 'day': 'Thursday 4 December 2025', 'time': '0915 - 1000', 'room': 'Cibolo Ballroom 8-9', 'description': 'Human Resiliency', 'tracks': ['Human Capital'], 'sponsor': None, 'speakers': [{'name': "Dr. Chaunte' Hall", 'role': 'CEO', 'organization': 'Path AI (', 'confirmed': False, 'invited': False}]}
# {'title': 'Breakout Session Track', 'day': 'Thursday 4 December 2025', 'time': '0915 - 1000', 'room': 'Cibolo Ballroom 1-2', 'description': 'Government Healthcare Session', 'tracks': ['Breakout Track'], 'sponsor': None, 'speakers': []}
# {'title': 'General Session', 'day': 'Thursday 4 December 2025', 'time': '1000 - 1100', 'room': 'Cibolo Ballroom 5-7', 'description': 'HAF/A2', 'tracks': ['General Session'], 'sponsor': None, 'speakers': [{'name': 'Lt. Gen. Max “Harpo” Pearson', 'role': 'Deputy Chief of Staff for Intelligence', 'organization': 'USAF (', 'confirmed': False, 'invited': False}]}
# {'title': 'Breakout Session Track', 'day': 'Thursday 4 December 2025', 'time': '1000 - 1100', 'room': 'Cibolo Ballroom 8-9', 'description': 'Resilience at the Edge Industry Panel', 'tracks': ['Breakout Track'], 'sponsor': None, 'speakers': []}
# {'title': 'Breakout Session Track', 'day': 'Thursday 4 December 2025', 'time': '1000 - 1100', 'room': 'Cibolo Ballroom 1-2', 'description': 'Emerging Leaders Panel', 'tracks': ['Breakout Track'], 'sponsor': None, 'speakers': []}
# {'title': 'General Session', 'day': 'Thursday 4 December 2025', 'time': '1100 - 1200', 'room': 'Cibolo Ballroom 5-7', 'description': None, 'tracks': ['General Session'], 'sponsor': None, 'speakers': []}
# {'title': 'Breakout Session Track', 'day': 'Thursday 4 December 2025', 'time': '1100 - 1200', 'room': 'Cibolo Ballroom 1-2', 'description': 'MAJCOM A6 Panel', 'tracks': ['Breakout Track'], 'sponsor': None, 'speakers': []}
# {'title': 'Breakout Session Track', 'day': 'Thursday 4 December 2025', 'time': '1100 - 1200', 'room': 'Cibolo Ballroom 8-9', 'description': 'State Cyber initiatives', 'tracks': ['Breakout Track'], 'sponsor': None, 'speakers': []}
# {'title': 'Technology Showcase Theater Presentations', 'day': 'Thursday 4 December 2025', 'time': '1145 - 1245', 'room': 'Azalea/Begonia/BluebonnetBottlebrush/Dogwood', 'description': 'Tech Showcases Sponsored by:\nSemper Valens Solutions, Inc.\nPresentations by:\nCanonical Group Limited\n|\nDynatrace\n|\nOkta\n|\nRancher Government Solutions\n|\nWebhead', 'tracks': ['Tech Showcase'], 'sponsor': 'Semper Valens Solutions, Inc.', 'speakers': []}
# {'title': 'Exhibit Hall Break', 'day': 'Thursday 4 December 2025', 'time': '1200 - 1245', 'room': 'Grand Oaks Ballroom', 'description': 'Break Sponsored By:\nQualys', 'tracks': [], 'sponsor': 'Qualys', 'speakers': []}
# {'title': 'Keynote Lunch', 'day': 'Thursday 4 December 2025', 'time': '1245 - 1415', 'room': 'Cibolo Ballroom 5-7', 'description': 'Scholarship Presentation; Keynote Lunch', 'tracks': ['Keynote Session'], 'sponsor': None, 'speakers': []}
# {'title': 'Exhibit Hall Break', 'day': 'Thursday 4 December 2025', 'time': '1415 - 1500', 'room': 'Grand Oaks Ballroom', 'description': 'Break Sponsored By:\nQualys', 'tracks': [], 'sponsor': 'Qualys', 'speakers': []}
# {'title': 'Technology Showcase Theater Presentations', 'day': 'Thursday 4 December 2025', 'time': '1415 - 1515', 'room': 'Begonia/BluebonnetBottlebrush/Dogwood', 'description': 'Tech Showcases Sponsored by:\nSemper Valens Solutions, Inc.\nPresentations by:\nAstrion\n|\nDelinea\n|\nForward Networks\n|\nOSC Edge', 'tracks': ['Tech Showcase'], 'sponsor': 'Semper Valens Solutions, Inc.', 'speakers': []}
# {'title': 'General Session', 'day': 'Thursday 4 December 2025', 'time': '1445 - 1600', 'room': 'Cibolo Ballroom 5-7', 'description': 'Senior Enlisted Leaders Panel', 'tracks': ['General Session'], 'sponsor': None, 'speakers': []}
# {'title': 'Breakout Session Track', 'day': 'Thursday 4 December 2025', 'time': '1445 - 1600', 'room': 'Cibolo Ballroom 1-2', 'description': 'NSA Commanders Panel', 'tracks': ['Breakout Track'], 'sponsor': None, 'speakers': []}
# {'title': 'Breakout Session Track', 'day': 'Thursday 4 December 2025', 'time': '1445 - 1600', 'room': 'Cibolo Ballroom 8-9', 'description': 'GovCon Industry Panel', 'tracks': ['Breakout Track'], 'sponsor': None, 'speakers': []}
# {'title': 'Exhibit Hall Break', 'day': 'Thursday 4 December 2025', 'time': '1600 - 1615', 'room': 'Grand Oaks Ballroom', 'description': 'Break Sponsored By:\nQualys', 'tracks': [], 'sponsor': 'Qualys', 'speakers': []}
# {'title': 'Keynote Session', 'day': 'Thursday 4 December 2025', 'time': '1615 - 1700', 'room': 'Cibolo Ballroom 5-7', 'description': 'HAF/A6 Update', 'tracks': ['Keynote Session'], 'sponsor': None, 'speakers': []}
# {'title': 'Hospitality', 'day': 'Thursday 4 December 2025', 'time': '1700 - 1900', 'room': 'TBD', 'description': 'Take Flight Thursday Hospitality\n\nSponsored By:\nVision IT Consultants, LLC', 'tracks': [], 'sponsor': 'Vision IT Consultants, LLC', 'speakers': []}
# {'title': 'Hospitality', 'day': 'Thursday 4 December 2025', 'time': '1700 - 1900', 'room': 'TBD', 'description': 'Emerging Leaders Hospitality\n\nSponsored By:\nDef-Logix, Inc.\n|\nMaximus', 'tracks': [], 'sponsor': 'Def-Logix, Inc.', 'speakers': []}
# {'title': 'Hospitality', 'day': 'Thursday 4 December 2025', 'time': '1700 - 1900', 'room': 'TBD', 'description': 'Small Business Hospitality', 'tracks': [], 'sponsor': None, 'speakers': []}
# {'title': 'Networking Hospitality Events', 'day': 'Thursday 4 December 2025', 'time': '1900 - 2100', 'room': 'The Sunday House', 'description': 'Sponsored By:\nCACI', 'tracks': [], 'sponsor': 'CACI', 'speakers': []}
# {'title': 'Classified Session', 'day': 'Friday 5 December 2025', 'time': '0700 - 1300', 'room': 'Bernard A. Larger Auditorium, 16th Air Force', 'description': 'Classified Session Details to ComeThis session requires TS/SCI - NOFORN security clearance and a separate registration.\n\nSponsored by:\nDell Technologies', 'tracks': ['Classified Session'], 'sponsor': 'Dell Technologies', 'speakers': []}
# {'title': 'Registration', 'day': 'Friday 5 December 2025', 'time': '0700 - 1200', 'room': '2nd Floor Ballroom Level', 'description': 'Sponsored By:\nPeraton', 'tracks': [], 'sponsor': 'Peraton', 'speakers': []}
# {'title': 'Breakfast', 'day': 'Friday 5 December 2025', 'time': '0700 - 0800', 'room': 'Grand Oaks Ballroom Foyer', 'description': 'Sponsored By:\nFlexera', 'tracks': [], 'sponsor': 'Flexera', 'speakers': []}
# {'title': 'Keynote Session', 'day': 'Friday 5 December 2025', 'time': '0800 - 0845', 'room': 'Cibolo Ballroom 5-7', 'description': 'Cyber Workforce', 'tracks': ['Keynote Session'], 'sponsor': None, 'speakers': []}
# {'title': 'General Session', 'day': 'Friday 5 December 2025', 'time': '0845 - 0930', 'room': 'Cibolo Ballroom 5-7', 'description': 'PEO C3BM', 'tracks': ['General Session'], 'sponsor': None, 'speakers': []}
# {'title': 'Small Business Track', 'day': 'Friday 5 December 2025', 'time': '0845 - 0930', 'room': 'Cibolo Ballroom 1-2', 'description': 'Cybersecurity Resilience for Small Businesses: FBI Perspectives', 'tracks': ['Small Business Track'], 'sponsor': None, 'speakers': [{'name': 'Mr. David Rodriguez', 'role': 'Supervisory Special', 'organization': 'FBI San Antonio - Cyber Task Force & CART (', 'confirmed': False, 'invited': False}]}
# {'title': 'Acquisition Track', 'day': 'Friday 5 December 2025', 'time': '0845 - 0930', 'room': 'Cibolo Ballroom 8-9', 'description': 'HNI\n\nAcquisition Track Sponsored by:\nSemper Valens Solutions, Inc.', 'tracks': ['Acquisition Track'], 'sponsor': 'Semper Valens Solutions, Inc.', 'speakers': []}
# {'title': 'Acquisition Track', 'day': 'Friday 5 December 2025', 'time': '0845 - 0930', 'room': 'Cibolo Ballroom 3-4', 'description': 'HNC\n\nAcquisition Track Sponsored by:\nSemper Valens Solutions, Inc.', 'tracks': ['Acquisition Track'], 'sponsor': 'Semper Valens Solutions, Inc.', 'speakers': []}
# {'title': 'Break', 'day': 'Friday 5 December 2025', 'time': '0930 - 0945', 'room': 'Grand Oaks Ballroom Foyer', 'description': 'Sponsored By:\nFlexera', 'tracks': [], 'sponsor': 'Flexera', 'speakers': []}
# {'title': 'General Session', 'day': 'Friday 5 December 2025', 'time': '0945 - 1100', 'room': 'Cibolo Ballroom 5-7', 'description': 'DHS CISA', 'tracks': ['General Session'], 'sponsor': None, 'speakers': []}
# {'title': 'Breakout Session Track', 'day': 'Friday 5 December 2025', 'time': '0945 - 1100', 'room': 'Cibolo Ballroom 1-2', 'description': 'Government Healthcare Session', 'tracks': ['Breakout Track'], 'sponsor': None, 'speakers': []}
# {'title': 'Acquisition Track', 'day': 'Friday 5 December 2025', 'time': '0945 - 1200', 'room': 'Cibolo Ballroom 8-9', 'description': 'Acquisition Presentations\n\nAcquisition Track Sponsored by:\nSemper Valens Solutions, Inc.', 'tracks': ['Acquisition Track'], 'sponsor': 'Semper Valens Solutions, Inc.', 'speakers': []}
# {'title': 'Acquisition Track', 'day': 'Friday 5 December 2025', 'time': '0945 - 1200', 'room': 'Cibolo Ballroom 3-4', 'description': 'Acquisition Presentations\n\nAcquisition Track Sponsored by:\nSemper Valens Solutions, Inc.', 'tracks': ['Acquisition Track'], 'sponsor': 'Semper Valens Solutions, Inc.', 'speakers': []}
# {'title': 'General Session', 'day': 'Friday 5 December 2025', 'time': '1100 - 1200', 'room': 'Cibolo Ballroom 5-7', 'description': 'CISO Panel', 'tracks': ['General Session'], 'sponsor': None, 'speakers': []}
# {'title': 'Small Business Track', 'day': 'Friday 5 December 2025', 'time': '1100 - 1200', 'room': 'Cibolo Ballroom 1-2', 'description': 'You have a great idea, now what? The first questions a hopeful entrepreneur should ask.', 'tracks': ['Small Business Track'], 'sponsor': None, 'speakers': []}

# %%
from llama_stack_client import LlamaStackClient

client = LlamaStackClient(base_url="http://lsd-llama-milvus-service.rag.svc.cluster.local:8321")

# %%
# Fetch all registered models
models = client.models.list()

print(models)

# %%
model_id = next(m.identifier for m in models if m.model_type == "llm")

embedding_model = next(m for m in models if m.model_type == "embedding")
embedding_model_id = embedding_model.identifier
embedding_dimension = embedding_model.metadata["embedding_dimension"]

# %%
vector_db_id = "my-milvus-db"
provider_id  = "milvus"

_ = client.vector_dbs.register(
vector_db_id=vector_db_id,
embedding_model=embedding_model_id,
embedding_dimension=embedding_dimension,
provider_id=provider_id,
)
print(f"Registered vector DB: {vector_db_id}")

# %%
dbs = client.vector_dbs.list()
identifier = dbs[0].identifier
print(identifier)

# %%
def session_to_text(session):
    speakers_str = "\n".join(
        [f"- {sp['name']} ({sp['role']}, {sp['organization']})"
         for sp in session['speakers']]
    )
    return f"""
    Title: {session['title']}
    Time: {session['time']}
    Room: {session['room']}
    Description: {session['description']}
    Tracks: {', '.join(session['tracks'])}
    Sponsor: {session['sponsor']}
    Speakers:
    {speakers_str}
    """

# %%
from llama_stack_client import RAGDocument

documents = []
for i, session in enumerate(sessions, start=1):
    text = session_to_text(session)
    documents.append(
        RAGDocument(
            document_id=f"session-{i}",
            content=text,
            mime_type="text/plain",
            metadata={
                "source": "https://www.alamoafcea.org/mpage/2025exhibitors",
                "type": "session",
                "title": session["title"],
                "time": session["time"],
                "room": session["room"],
                "tracks": session["tracks"],
                "sponsor": session["sponsor"]
            }
        )
    )

batch_size = 10
for i in range(0, len(documents), batch_size):
    batch = documents[i:i+batch_size]
    client.tool_runtime.rag_tool.insert(
        documents=batch,
        vector_db_id=identifier,
        chunk_size_in_tokens=200,
        timeout=60
    )
print("Sessions ingested successfully")

# %%
query="Which sessions cover AI in the Indo-Pacific?"

result = client.tool_runtime.rag_tool.query(
    vector_db_ids=[identifier],
    content=query,
)
print("Low-level query result:", result)

# %%
query = "Which sessions cover AI in the Indo-Pacific?"

result = client.tool_runtime.rag_tool.query(
    vector_db_ids=[identifier],
    content=query,
)

print(f"Query: {query}\n")

# Deduplicate by document_id
seen = set()
for i, match in enumerate(result.metadata["document_ids"]):
    doc_id = result.metadata["document_ids"][i]
    chunk_text = result.metadata["chunks"][i]
    score = result.metadata["scores"][i]

    if doc_id in seen:
        continue
    seen.add(doc_id)

    print(f"Result {len(seen)} (score={score:.3f})")
    print(chunk_text.strip()[:500])  # show first ~500 chars
    print("-" * 80)

# %%
dbs = client.vector_dbs.list()
if not dbs:
    print("No vector DBs found.")

for db in dbs:
    try:
        print(f"Unregistering {db.vector_db_name} ({db.identifier}) ...")
        client.vector_dbs.unregister(db.identifier)
        print(f"✔ Deleted {db.identifier}")
    except Exception as e:
        print(f"⚠ Failed to delete {db.identifier}: {e}")
